# %%
import tensorflow as tf
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
train_dir='dataset/train'
test_dir='dataset/valid'

# %%
batch_size = 20
epochs = 5
img_height = 224
img_width = 224

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)  
train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,directory=train_dir,shuffle=True,target_size=(img_height, img_width),class_mode='categorical')
# Out:
# Found 979 images belonging to 3 classes.

# %%
val_image_generator = ImageDataGenerator(rescale=1./255)  
val_data_gen = val_image_generator .flow_from_directory(batch_size=batch_size,directory=test_dir,shuffle=True,target_size=(img_height, img_width),class_mode='categorical')
# Out:
# Found 187 images belonging to 3 classes.

# %%
import warnings
 

import os
import glob
import matplotlib.pyplot as plt

# Import Keras
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D,Activation,AveragePooling2D,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

# %%
img_width,img_height =224,224
input_shape=(img_width,img_height,3)

# %%
model = Sequential()
model.add(Conv2D(32, (5, 5),input_shape=input_shape,activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))   
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(128,activation='relu'))          
model.add(Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 71, 71, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 35, 35, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               8389120
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 8,485,347
# Trainable params: 8,485,347
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
history = model.fit(train_data_gen, epochs=45,
validation_data= val_data_gen,)
# Out:
# Epoch 1/45
# 49/49 [==============================] - 19s 373ms/step - loss: 1.0754 - accuracy: 0.4392 - val_loss: 0.7562 - val_accuracy: 0.7059
# Epoch 2/45
# 49/49 [==============================] - 21s 437ms/step - loss: 0.5819 - accuracy: 0.7681 - val_loss: 0.3646 - val_accuracy: 0.8770
# Epoch 3/45
# 49/49 [==============================] - 21s 428ms/step - loss: 0.3390 - accuracy: 0.8723 - val_loss: 0.2395 - val_accuracy: 0.9198
# Epoch 4/45
# 49/49 [==============================] - 21s 434ms/step - loss: 0.2106 - accuracy: 0.9244 - val_loss: 0.2005 - val_accuracy: 0.9198
# Epoch 5/45
# 49/49 [==============================] - 21s 435ms/step - loss: 0.1197 - accuracy: 0.9612 - val_loss: 0.1992 - val_accuracy: 0.9251
# Epoch 6/45
# 49/49 [==============================] - 21s 427ms/step - loss: 0.1102 - accuracy: 0.9571 - val_loss: 0.2693 - val_accuracy: 0.9465
# Epoch 7/45
# 49/49 [==============================] - 21s 434ms/step - loss: 0.0606 - accuracy: 0.9816 - val_loss: 0.2747 - val_accuracy: 0.9305
# Epoch 8/45
# 49/49 [==============================] - 21s 433ms/step - loss: 0.0441 - accuracy: 0.9837 - val_loss: 0.4018 - val_accuracy: 0.9519
# Epoch 9/45
# 49/49 [==============================] - 21s 438ms/step - loss: 0.0427 - accuracy: 0.9867 - val_loss: 0.2715 - val_accuracy: 0.9572
# Epoch 10/45
# 49/49 [==============================] - 22s 441ms/step - loss: 0.0446 - accuracy: 0.9857 - val_loss: 0.3151 - val_accuracy: 0.9198
# Epoch 11/45
# 49/49 [==============================] - 22s 440ms/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 0.3802 - val_accuracy: 0.9519
# Epoch 12/45
# 49/49 [==============================] - 20s 408ms/step - loss: 0.0215 - accuracy: 0.9949 - val_loss: 0.3186 - val_accuracy: 0.9572
# Epoch 13/45
# 49/49 [==============================] - 21s 431ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.3746 - val_accuracy: 0.9519
# Epoch 14/45
# 49/49 [==============================] - 21s 432ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.4202 - val_accuracy: 0.9465
# Epoch 15/45
# 49/49 [==============================] - 21s 430ms/step - loss: 0.0211 - accuracy: 0.9949 - val_loss: 0.2927 - val_accuracy: 0.9358
# Epoch 16/45
# 49/49 [==============================] - 21s 430ms/step - loss: 0.0242 - accuracy: 0.9959 - val_loss: 0.4418 - val_accuracy: 0.9465
# Epoch 17/45
# 49/49 [==============================] - 21s 428ms/step - loss: 0.0425 - accuracy: 0.9888 - val_loss: 0.2908 - val_accuracy: 0.9305
# Epoch 18/45
# 49/49 [==============================] - 20s 413ms/step - loss: 0.0613 - accuracy: 0.9796 - val_loss: 0.2998 - val_accuracy: 0.9572
# Epoch 19/45
# 49/49 [==============================] - 20s 416ms/step - loss: 0.0297 - accuracy: 0.9908 - val_loss: 0.4815 - val_accuracy: 0.9144
# Epoch 20/45
# 49/49 [==============================] - 22s 440ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.5593 - val_accuracy: 0.9358
# Epoch 21/45
# 49/49 [==============================] - 21s 437ms/step - loss: 0.0103 - accuracy: 0.9959 - val_loss: 0.3046 - val_accuracy: 0.9412
# Epoch 22/45
# 49/49 [==============================] - 21s 426ms/step - loss: 0.0199 - accuracy: 0.9980 - val_loss: 0.3427 - val_accuracy: 0.9465
# Epoch 23/45
# 49/49 [==============================] - 21s 427ms/step - loss: 0.0127 - accuracy: 0.9980 - val_loss: 0.3923 - val_accuracy: 0.9519
# Epoch 24/45
# 49/49 [==============================] - 21s 423ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.3218 - val_accuracy: 0.9465
# Epoch 25/45
# 49/49 [==============================] - 20s 401ms/step - loss: 0.0119 - accuracy: 0.9969 - val_loss: 0.4525 - val_accuracy: 0.9358
# Epoch 26/45
# 49/49 [==============================] - 20s 416ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.4919 - val_accuracy: 0.9465
# Epoch 27/45
# 49/49 [==============================] - 20s 410ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.5160 - val_accuracy: 0.9412
# Epoch 28/45
# 49/49 [==============================] - 21s 427ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.4203 - val_accuracy: 0.9572
# Epoch 29/45
# 49/49 [==============================] - 21s 425ms/step - loss: 0.0099 - accuracy: 0.9980 - val_loss: 0.4048 - val_accuracy: 0.9519
# Epoch 30/45
# 49/49 [==============================] - 21s 429ms/step - loss: 0.0131 - accuracy: 0.9969 - val_loss: 0.3102 - val_accuracy: 0.9358
# Epoch 31/45
# 49/49 [==============================] - 21s 425ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.3378 - val_accuracy: 0.9412
# Epoch 32/45
# 49/49 [==============================] - 23s 464ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3449 - val_accuracy: 0.9519
# Epoch 33/45
# 49/49 [==============================] - 21s 424ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.6652 - val_accuracy: 0.9626
# Epoch 34/45
# 49/49 [==============================] - 21s 427ms/step - loss: 0.0059 - accuracy: 0.9969 - val_loss: 0.4681 - val_accuracy: 0.9572
# Epoch 35/45
# 49/49 [==============================] - 20s 410ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.4732 - val_accuracy: 0.9412
# Epoch 36/45
# 49/49 [==============================] - 21s 423ms/step - loss: 0.0292 - accuracy: 0.9928 - val_loss: 0.3517 - val_accuracy: 0.9305
# Epoch 37/45
# 49/49 [==============================] - 20s 417ms/step - loss: 0.0301 - accuracy: 0.9918 - val_loss: 0.5461 - val_accuracy: 0.9251
# Epoch 38/45
# 49/49 [==============================] - 20s 417ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 0.2346 - val_accuracy: 0.9733
# Epoch 39/45
# 49/49 [==============================] - 20s 405ms/step - loss: 0.0203 - accuracy: 0.9969 - val_loss: 0.4332 - val_accuracy: 0.9572
# Epoch 40/45
# 49/49 [==============================] - 20s 403ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.2604 - val_accuracy: 0.9519
# Epoch 41/45
# 49/49 [==============================] - 21s 427ms/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.3760 - val_accuracy: 0.9412
# Epoch 42/45
# 49/49 [==============================] - 20s 400ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.6131 - val_accuracy: 0.9465
# Epoch 43/45
# 49/49 [==============================] - 21s 423ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.5738 - val_accuracy: 0.9626
# Epoch 44/45
# 49/49 [==============================] - 22s 450ms/step - loss: 0.0504 - accuracy: 0.9826 - val_loss: 0.4851 - val_accuracy: 0.9465
# Epoch 45/45
# 49/49 [==============================] - 22s 443ms/step - loss: 0.0670 - accuracy: 0.9806 - val_loss: 0.2464 - val_accuracy: 0.9679

# %%
import numpy as np

# %%
y=np.concatenate([val_data_gen.next()[1] for i in range(val_data_gen.__len__())])
true_labels=np.argmax(y, axis=-1)
prediction= model.predict(val_data_gen, verbose=2)
prediction=np.argmax(prediction, axis=-1)
# Out:
# 10/10 - 1s

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
cm = confusion_matrix(y_true=true_labels, y_pred=prediction)

# %%
cm_plot_labels = ['empty','full','normal']

# %%
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
from sklearn.metrics import accuracy_score
acc=accuracy_score(true_labels,prediction) 
print('Accuracy: %.3f' % acc)
from sklearn.metrics import precision_score
precision = precision_score(true_labels,prediction,labels=[1,2], average='micro')
print('Precision: %.3f' % precision)
from sklearn.metrics import recall_score
recall = recall_score(true_labels,prediction, average='micro')
print('Recall: %.3f' % recall)
from sklearn.metrics import f1_score
score = f1_score(true_labels,prediction, average='micro')
print('F-Measure: %.3f' % score)
# Out:
# Confusion matrix, without normalization
# [[70  0  0]
#  [ 0 60  0]
#  [ 1  5 51]]
# Accuracy: 0.968
# Precision: 0.957
# Recall: 0.968
# F-Measure: 0.968

# %%
model.save('savecopy.h5')
